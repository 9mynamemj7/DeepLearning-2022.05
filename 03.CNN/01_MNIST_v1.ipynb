# %% [markdown]
# # MNIST 손글씨 - CNN v1
# - 2 x Conv2D layers
# - 1 FCN layer
# - 1 Output layer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# X_train, X_test 정규화 (0 ~ 1), 이미지 차원 변경: 2차원 --> 3차원
X_train = X_train.reshape(-1, 28, 28, 1) / 255.
X_test = X_test.reshape(-1, 28, 28, 1) / 255.
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
# One hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 18,898,826
# Trainable params: 18,898,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

# %%
model_path = 'best-mnist-cnn-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2, epochs=100, batch_size=200,
    callbacks=[mc,es]
)
# Out:
# Epoch 1/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9531
# Epoch 1: val_loss improved from inf to 0.05521, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 11s 27ms/step - loss: 0.1518 - accuracy: 0.9531 - val_loss: 0.0552 - val_accuracy: 0.9838
# Epoch 2/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9893
# Epoch 2: val_loss improved from 0.05521 to 0.05420, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 5s 22ms/step - loss: 0.0353 - accuracy: 0.9893 - val_loss: 0.0542 - val_accuracy: 0.9852
# Epoch 3/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9944
# Epoch 3: val_loss improved from 0.05420 to 0.04817, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 5s 23ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0482 - val_accuracy: 0.9876
# Epoch 4/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9963
# Epoch 4: val_loss did not improve from 0.04817
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0526 - val_accuracy: 0.9861
# Epoch 5/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9971
# Epoch 5: val_loss did not improve from 0.04817
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0530 - val_accuracy: 0.9871
# Epoch 6/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9983
# Epoch 6: val_loss improved from 0.04817 to 0.04804, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 5s 23ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0480 - val_accuracy: 0.9882
# Epoch 7/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 7: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0630 - val_accuracy: 0.9862
# Epoch 8/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9984
# Epoch 8: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0553 - val_accuracy: 0.9887
# Epoch 9/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 9: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0576 - val_accuracy: 0.9879
# Epoch 10/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9983
# Epoch 10: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0635 - val_accuracy: 0.9873
# Epoch 11/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 11: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0572 - val_accuracy: 0.9893
# Epoch 12/100
# 238/240 [============================>.] - ETA: 0s - loss: 1.7544e-04 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 20ms/step - loss: 1.7516e-04 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9904
# Epoch 13/100
# 238/240 [============================>.] - ETA: 0s - loss: 5.2806e-05 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 21ms/step - loss: 5.2445e-05 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9914
# Epoch 14/100
# 238/240 [============================>.] - ETA: 0s - loss: 1.3922e-05 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 21ms/step - loss: 1.3937e-05 - accuracy: 1.0000 - val_loss: 0.0572 - val_accuracy: 0.9913
# Epoch 15/100
# 238/240 [============================>.] - ETA: 0s - loss: 1.0196e-05 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 21ms/step - loss: 1.0191e-05 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9913
# Epoch 16/100
# 239/240 [============================>.] - ETA: 0s - loss: 7.8774e-06 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.04804
# 240/240 [==============================] - 5s 21ms/step - loss: 7.9080e-06 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9913

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0385 - accuracy: 0.9888
# [0.03845120221376419, 0.9887999892234802]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.title('MNIST_v1', size=20)
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')


# plt.plot(xs, y_vloss1, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('Epoch')
plt.show()
