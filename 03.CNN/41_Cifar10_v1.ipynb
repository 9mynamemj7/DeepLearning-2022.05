# %% [markdown]
# # Cifar-10 이미지 분류 - v1

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
seed = 2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1), (10000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]])
plt.show()

# %%
# X_data: scaling
X_train = X_train/255.
X_test = X_test/255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax'),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 32)          0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 512)               590336
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 642,570
# Trainable params: 642,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2, epochs=100,
    batch_size=32, callbacks=[mc,es]
)
# Out:
# Epoch 1/100
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.8882 - accuracy: 0.3034
# Epoch 1: val_loss improved from inf to 1.63625, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 19s 6ms/step - loss: 1.8863 - accuracy: 0.3041 - val_loss: 1.6363 - val_accuracy: 0.4030
# Epoch 2/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.5888 - accuracy: 0.4190
# Epoch 2: val_loss improved from 1.63625 to 1.45578, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.5886 - accuracy: 0.4191 - val_loss: 1.4558 - val_accuracy: 0.4753
# Epoch 3/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.4602 - accuracy: 0.4688
# Epoch 3: val_loss improved from 1.45578 to 1.34644, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.4599 - accuracy: 0.4691 - val_loss: 1.3464 - val_accuracy: 0.5231
# Epoch 4/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.3713 - accuracy: 0.5071
# Epoch 4: val_loss improved from 1.34644 to 1.28674, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.3713 - accuracy: 0.5069 - val_loss: 1.2867 - val_accuracy: 0.5395
# Epoch 5/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.3013 - accuracy: 0.5344
# Epoch 5: val_loss improved from 1.28674 to 1.27376, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.3010 - accuracy: 0.5346 - val_loss: 1.2738 - val_accuracy: 0.5484
# Epoch 6/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.2414 - accuracy: 0.5581
# Epoch 6: val_loss improved from 1.27376 to 1.15395, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.2413 - accuracy: 0.5582 - val_loss: 1.1539 - val_accuracy: 0.5961
# Epoch 7/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.1922 - accuracy: 0.5777
# Epoch 7: val_loss improved from 1.15395 to 1.11838, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.1924 - accuracy: 0.5775 - val_loss: 1.1184 - val_accuracy: 0.6071
# Epoch 8/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.1495 - accuracy: 0.5933
# Epoch 8: val_loss improved from 1.11838 to 1.06351, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.1486 - accuracy: 0.5933 - val_loss: 1.0635 - val_accuracy: 0.6247
# Epoch 9/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.1070 - accuracy: 0.6099
# Epoch 9: val_loss improved from 1.06351 to 1.04202, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.1069 - accuracy: 0.6099 - val_loss: 1.0420 - val_accuracy: 0.6353
# Epoch 10/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.0751 - accuracy: 0.6202
# Epoch 10: val_loss improved from 1.04202 to 1.03344, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.0749 - accuracy: 0.6202 - val_loss: 1.0334 - val_accuracy: 0.6345
# Epoch 11/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0419 - accuracy: 0.6359
# Epoch 11: val_loss improved from 1.03344 to 0.97242, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.0419 - accuracy: 0.6359 - val_loss: 0.9724 - val_accuracy: 0.6617
# Epoch 12/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0137 - accuracy: 0.6418
# Epoch 12: val_loss did not improve from 0.97242
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.0137 - accuracy: 0.6418 - val_loss: 0.9729 - val_accuracy: 0.6629
# Epoch 13/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9848 - accuracy: 0.6550
# Epoch 13: val_loss improved from 0.97242 to 0.93154, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9846 - accuracy: 0.6551 - val_loss: 0.9315 - val_accuracy: 0.6743
# Epoch 14/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.9632 - accuracy: 0.6604
# Epoch 14: val_loss improved from 0.93154 to 0.88896, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9629 - accuracy: 0.6605 - val_loss: 0.8890 - val_accuracy: 0.6877
# Epoch 15/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.9338 - accuracy: 0.6723
# Epoch 15: val_loss improved from 0.88896 to 0.88655, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9336 - accuracy: 0.6725 - val_loss: 0.8865 - val_accuracy: 0.6911
# Epoch 16/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.9197 - accuracy: 0.6794
# Epoch 16: val_loss improved from 0.88655 to 0.88401, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9202 - accuracy: 0.6792 - val_loss: 0.8840 - val_accuracy: 0.6894
# Epoch 17/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.8999 - accuracy: 0.6847
# Epoch 17: val_loss improved from 0.88401 to 0.84066, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8997 - accuracy: 0.6847 - val_loss: 0.8407 - val_accuracy: 0.7060
# Epoch 18/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.8831 - accuracy: 0.6910
# Epoch 18: val_loss improved from 0.84066 to 0.82702, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8832 - accuracy: 0.6910 - val_loss: 0.8270 - val_accuracy: 0.7098
# Epoch 19/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.8679 - accuracy: 0.6974
# Epoch 19: val_loss improved from 0.82702 to 0.80986, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8680 - accuracy: 0.6974 - val_loss: 0.8099 - val_accuracy: 0.7143
# Epoch 20/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8551 - accuracy: 0.7017
# Epoch 20: val_loss did not improve from 0.80986
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8545 - accuracy: 0.7017 - val_loss: 0.8323 - val_accuracy: 0.7095
# Epoch 21/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.8415 - accuracy: 0.7066
# Epoch 21: val_loss improved from 0.80986 to 0.80119, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8411 - accuracy: 0.7068 - val_loss: 0.8012 - val_accuracy: 0.7183
# Epoch 22/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8226 - accuracy: 0.7132
# Epoch 22: val_loss did not improve from 0.80119
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8224 - accuracy: 0.7132 - val_loss: 0.8021 - val_accuracy: 0.7198
# Epoch 23/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.8118 - accuracy: 0.7165
# Epoch 23: val_loss improved from 0.80119 to 0.78153, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8125 - accuracy: 0.7163 - val_loss: 0.7815 - val_accuracy: 0.7269
# Epoch 24/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.8012 - accuracy: 0.7207
# Epoch 24: val_loss did not improve from 0.78153
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8013 - accuracy: 0.7208 - val_loss: 0.7820 - val_accuracy: 0.7239
# Epoch 25/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7931 - accuracy: 0.7242
# Epoch 25: val_loss improved from 0.78153 to 0.75678, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7931 - accuracy: 0.7242 - val_loss: 0.7568 - val_accuracy: 0.7342
# Epoch 26/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7797 - accuracy: 0.7271
# Epoch 26: val_loss improved from 0.75678 to 0.74944, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7800 - accuracy: 0.7270 - val_loss: 0.7494 - val_accuracy: 0.7351
# Epoch 27/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7726 - accuracy: 0.7321
# Epoch 27: val_loss improved from 0.74944 to 0.74504, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7729 - accuracy: 0.7320 - val_loss: 0.7450 - val_accuracy: 0.7389
# Epoch 28/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7679 - accuracy: 0.7353
# Epoch 28: val_loss improved from 0.74504 to 0.73207, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7684 - accuracy: 0.7350 - val_loss: 0.7321 - val_accuracy: 0.7428
# Epoch 29/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7554 - accuracy: 0.7369
# Epoch 29: val_loss did not improve from 0.73207
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7551 - accuracy: 0.7373 - val_loss: 0.7396 - val_accuracy: 0.7382
# Epoch 30/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7526 - accuracy: 0.7383
# Epoch 30: val_loss improved from 0.73207 to 0.72446, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7528 - accuracy: 0.7381 - val_loss: 0.7245 - val_accuracy: 0.7462
# Epoch 31/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.7399 - accuracy: 0.7450
# Epoch 31: val_loss did not improve from 0.72446
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7399 - accuracy: 0.7452 - val_loss: 0.7273 - val_accuracy: 0.7453
# Epoch 32/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7331 - accuracy: 0.7465
# Epoch 32: val_loss did not improve from 0.72446
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7338 - accuracy: 0.7463 - val_loss: 0.7275 - val_accuracy: 0.7454
# Epoch 33/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7248 - accuracy: 0.7485
# Epoch 33: val_loss improved from 0.72446 to 0.71601, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7248 - accuracy: 0.7484 - val_loss: 0.7160 - val_accuracy: 0.7488
# Epoch 34/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.7242 - accuracy: 0.7481
# Epoch 34: val_loss improved from 0.71601 to 0.70963, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7240 - accuracy: 0.7483 - val_loss: 0.7096 - val_accuracy: 0.7480
# Epoch 35/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7169 - accuracy: 0.7494
# Epoch 35: val_loss did not improve from 0.70963
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7164 - accuracy: 0.7496 - val_loss: 0.7171 - val_accuracy: 0.7509
# Epoch 36/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.7127 - accuracy: 0.7529
# Epoch 36: val_loss improved from 0.70963 to 0.70925, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7129 - accuracy: 0.7531 - val_loss: 0.7093 - val_accuracy: 0.7523
# Epoch 37/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.7562
# Epoch 37: val_loss improved from 0.70925 to 0.69370, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7067 - accuracy: 0.7562 - val_loss: 0.6937 - val_accuracy: 0.7555
# Epoch 38/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7021 - accuracy: 0.7568
# Epoch 38: val_loss did not improve from 0.69370
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7024 - accuracy: 0.7567 - val_loss: 0.6965 - val_accuracy: 0.7557
# Epoch 39/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6929 - accuracy: 0.7585
# Epoch 39: val_loss did not improve from 0.69370
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6935 - accuracy: 0.7583 - val_loss: 0.7031 - val_accuracy: 0.7515
# Epoch 40/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.7623
# Epoch 40: val_loss improved from 0.69370 to 0.67989, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6877 - accuracy: 0.7623 - val_loss: 0.6799 - val_accuracy: 0.7638
# Epoch 41/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6870 - accuracy: 0.7623
# Epoch 41: val_loss did not improve from 0.67989
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6870 - accuracy: 0.7623 - val_loss: 0.7012 - val_accuracy: 0.7525
# Epoch 42/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.7651
# Epoch 42: val_loss did not improve from 0.67989
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6820 - accuracy: 0.7653 - val_loss: 0.7029 - val_accuracy: 0.7518
# Epoch 43/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6761 - accuracy: 0.7661
# Epoch 43: val_loss did not improve from 0.67989
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6764 - accuracy: 0.7661 - val_loss: 0.6839 - val_accuracy: 0.7616
# Epoch 44/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6783 - accuracy: 0.7647
# Epoch 44: val_loss did not improve from 0.67989
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6783 - accuracy: 0.7647 - val_loss: 0.6811 - val_accuracy: 0.7623
# Epoch 45/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6736 - accuracy: 0.7670
# Epoch 45: val_loss improved from 0.67989 to 0.67907, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6743 - accuracy: 0.7667 - val_loss: 0.6791 - val_accuracy: 0.7677
# Epoch 46/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6653 - accuracy: 0.7716
# Epoch 46: val_loss improved from 0.67907 to 0.67814, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6662 - accuracy: 0.7714 - val_loss: 0.6781 - val_accuracy: 0.7602
# Epoch 47/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6667 - accuracy: 0.7690
# Epoch 47: val_loss improved from 0.67814 to 0.67034, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6669 - accuracy: 0.7689 - val_loss: 0.6703 - val_accuracy: 0.7669
# Epoch 48/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6614 - accuracy: 0.7715
# Epoch 48: val_loss improved from 0.67034 to 0.66328, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6614 - accuracy: 0.7715 - val_loss: 0.6633 - val_accuracy: 0.7734
# Epoch 49/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6608 - accuracy: 0.7723
# Epoch 49: val_loss did not improve from 0.66328
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6609 - accuracy: 0.7721 - val_loss: 0.6645 - val_accuracy: 0.7705
# Epoch 50/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6572 - accuracy: 0.7737
# Epoch 50: val_loss did not improve from 0.66328
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6569 - accuracy: 0.7737 - val_loss: 0.6792 - val_accuracy: 0.7636
# Epoch 51/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6559 - accuracy: 0.7731
# Epoch 51: val_loss did not improve from 0.66328
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6558 - accuracy: 0.7732 - val_loss: 0.6710 - val_accuracy: 0.7695
# Epoch 52/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6563 - accuracy: 0.7747
# Epoch 52: val_loss did not improve from 0.66328
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6570 - accuracy: 0.7747 - val_loss: 0.6634 - val_accuracy: 0.7699
# Epoch 53/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6438 - accuracy: 0.7793
# Epoch 53: val_loss did not improve from 0.66328
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6443 - accuracy: 0.7793 - val_loss: 0.6701 - val_accuracy: 0.7708
# Epoch 54/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6455 - accuracy: 0.7786
# Epoch 54: val_loss improved from 0.66328 to 0.66231, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6456 - accuracy: 0.7785 - val_loss: 0.6623 - val_accuracy: 0.7708
# Epoch 55/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6454 - accuracy: 0.7782
# Epoch 55: val_loss did not improve from 0.66231
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6454 - accuracy: 0.7782 - val_loss: 0.6676 - val_accuracy: 0.7720
# Epoch 56/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.7802
# Epoch 56: val_loss improved from 0.66231 to 0.66133, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6414 - accuracy: 0.7797 - val_loss: 0.6613 - val_accuracy: 0.7776
# Epoch 57/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.6412 - accuracy: 0.7812
# Epoch 57: val_loss improved from 0.66133 to 0.65460, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6411 - accuracy: 0.7815 - val_loss: 0.6546 - val_accuracy: 0.7743
# Epoch 58/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6416 - accuracy: 0.7802
# Epoch 58: val_loss did not improve from 0.65460
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6417 - accuracy: 0.7801 - val_loss: 0.6651 - val_accuracy: 0.7720
# Epoch 59/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6329 - accuracy: 0.7832
# Epoch 59: val_loss did not improve from 0.65460
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6329 - accuracy: 0.7832 - val_loss: 0.6648 - val_accuracy: 0.7771
# Epoch 60/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6396 - accuracy: 0.7827
# Epoch 60: val_loss improved from 0.65460 to 0.64597, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6400 - accuracy: 0.7827 - val_loss: 0.6460 - val_accuracy: 0.7792
# Epoch 61/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6365 - accuracy: 0.7827
# Epoch 61: val_loss did not improve from 0.64597
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6363 - accuracy: 0.7826 - val_loss: 0.6527 - val_accuracy: 0.7773
# Epoch 62/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6309 - accuracy: 0.7840
# Epoch 62: val_loss did not improve from 0.64597
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6312 - accuracy: 0.7840 - val_loss: 0.6568 - val_accuracy: 0.7723
# Epoch 63/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6329 - accuracy: 0.7836
# Epoch 63: val_loss did not improve from 0.64597
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6334 - accuracy: 0.7833 - val_loss: 0.6706 - val_accuracy: 0.7733
# Epoch 64/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.6295 - accuracy: 0.7830
# Epoch 64: val_loss did not improve from 0.64597
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6287 - accuracy: 0.7832 - val_loss: 0.6522 - val_accuracy: 0.7774
# Epoch 65/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6295 - accuracy: 0.7859
# Epoch 65: val_loss did not improve from 0.64597
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6294 - accuracy: 0.7858 - val_loss: 0.6820 - val_accuracy: 0.7712
# Epoch 66/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6298 - accuracy: 0.7844
# Epoch 66: val_loss did not improve from 0.64597
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6298 - accuracy: 0.7844 - val_loss: 0.6596 - val_accuracy: 0.7792
# Epoch 67/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6239 - accuracy: 0.7876
# Epoch 67: val_loss improved from 0.64597 to 0.64205, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6240 - accuracy: 0.7876 - val_loss: 0.6420 - val_accuracy: 0.7853
# Epoch 68/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6255 - accuracy: 0.7874
# Epoch 68: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6257 - accuracy: 0.7873 - val_loss: 0.6514 - val_accuracy: 0.7790
# Epoch 69/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.7874
# Epoch 69: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6295 - accuracy: 0.7874 - val_loss: 0.6670 - val_accuracy: 0.7724
# Epoch 70/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6261 - accuracy: 0.7846
# Epoch 70: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6260 - accuracy: 0.7848 - val_loss: 0.6517 - val_accuracy: 0.7802
# Epoch 71/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6276 - accuracy: 0.7876
# Epoch 71: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6277 - accuracy: 0.7876 - val_loss: 0.6512 - val_accuracy: 0.7828
# Epoch 72/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.7856
# Epoch 72: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6284 - accuracy: 0.7855 - val_loss: 0.6685 - val_accuracy: 0.7763
# Epoch 73/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.6234 - accuracy: 0.7898
# Epoch 73: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6238 - accuracy: 0.7896 - val_loss: 0.6536 - val_accuracy: 0.7810
# Epoch 74/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6197 - accuracy: 0.7896
# Epoch 74: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6201 - accuracy: 0.7894 - val_loss: 0.6688 - val_accuracy: 0.7742
# Epoch 75/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6213 - accuracy: 0.7886
# Epoch 75: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6214 - accuracy: 0.7885 - val_loss: 0.6493 - val_accuracy: 0.7793
# Epoch 76/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6257 - accuracy: 0.7898
# Epoch 76: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6256 - accuracy: 0.7899 - val_loss: 0.6514 - val_accuracy: 0.7806
# Epoch 77/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6229 - accuracy: 0.7897
# Epoch 77: val_loss did not improve from 0.64205
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6230 - accuracy: 0.7896 - val_loss: 0.6958 - val_accuracy: 0.7662

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6565 - accuracy: 0.7796
# [0.6565040946006775, 0.7796000242233276]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

plt.figure(figsize=(12,8))
plt.title('Cifar-10', size=20)
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('Epoch')
plt.show()
