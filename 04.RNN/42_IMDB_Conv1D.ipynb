# %% [markdown]
# # IMDB 영화리뷰 감성분석 - Conv1D
# - Conv1D + Conv1D + Dense
# - Conv1D + LSTM + Dense
# - Conv1D + Dense + Dense

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
num_words = 10000
(X_train, y_train), (_, _) = imdb.load_data(num_words=num_words)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train, stratify=y_train, test_size=0.2, random_state=seed
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((20000,), (5000,), (20000,), (5000,))

# %%
max_len = 500
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)
X_train.shape, X_test.shape
# Out:
# ((20000, 500), (5000, 500))

# %% [markdown]
# - Case 1) Conv1D x 2

# %%
model1 = Sequential([
    Embedding(num_words, 100, input_length=max_len),
    Dropout(0.5),
    Conv1D(64, 7, activation='relu'),
    MaxPooling1D(7),
    Conv1D(64, 5, activation='relu'),
    MaxPooling1D(5),
    GlobalMaxPooling1D(),
    Dense(1, activation='sigmoid')
])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 100)          1000000
#
#  dropout (Dropout)           (None, 500, 100)          0
#
#  conv1d (Conv1D)             (None, 494, 64)           44864
#
#  max_pooling1d (MaxPooling1D  (None, 70, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 66, 64)            20544
#
#  max_pooling1d_1 (MaxPooling  (None, 13, 64)           0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 1,065,473
# Trainable params: 1,065,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile('adam', 'binary_crossentropy', ['accuracy'])
model_path1 = 'best-imdb-conv1d-conv1d.h5'
mc1 = ModelCheckpoint(model_path1, verbose=1, save_best_only=True)
es1 = EarlyStopping(patience=10)
hist1 = model1.fit(
    X_train, y_train, validation_split=0.2,
    epochs=30, batch_size=64, callbacks=[mc1,es1]
)
best_model1 = load_model(model_path1)
best_model1.evaluate(X_test, y_test)
# Out:
# Epoch 1/30
# 247/250 [============================>.] - ETA: 0s - loss: 0.5602 - accuracy: 0.6752
# Epoch 1: val_loss improved from inf to 0.36101, saving model to best-imdb-conv1d-conv1d.h5
# 250/250 [==============================] - 15s 10ms/step - loss: 0.5573 - accuracy: 0.6777 - val_loss: 0.3610 - val_accuracy: 0.8470
# Epoch 2/30
# 245/250 [============================>.] - ETA: 0s - loss: 0.2879 - accuracy: 0.8821
# Epoch 2: val_loss improved from 0.36101 to 0.32325, saving model to best-imdb-conv1d-conv1d.h5
# 250/250 [==============================] - 2s 9ms/step - loss: 0.2886 - accuracy: 0.8818 - val_loss: 0.3232 - val_accuracy: 0.8627
# Epoch 3/30
# 245/250 [============================>.] - ETA: 0s - loss: 0.1944 - accuracy: 0.9268
# Epoch 3: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.1945 - accuracy: 0.9268 - val_loss: 0.3470 - val_accuracy: 0.8545
# Epoch 4/30
# 248/250 [============================>.] - ETA: 0s - loss: 0.1332 - accuracy: 0.9524
# Epoch 4: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.1332 - accuracy: 0.9524 - val_loss: 0.3691 - val_accuracy: 0.8658
# Epoch 5/30
# 248/250 [============================>.] - ETA: 0s - loss: 0.0865 - accuracy: 0.9688
# Epoch 5: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.0873 - accuracy: 0.9686 - val_loss: 0.4452 - val_accuracy: 0.8568
# Epoch 6/30
# 250/250 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9805
# Epoch 6: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.0565 - accuracy: 0.9805 - val_loss: 0.5406 - val_accuracy: 0.8602
# Epoch 7/30
# 245/250 [============================>.] - ETA: 0s - loss: 0.0407 - accuracy: 0.9851
# Epoch 7: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0410 - accuracy: 0.9851 - val_loss: 0.6436 - val_accuracy: 0.8530
# Epoch 8/30
# 244/250 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9893
# Epoch 8: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.0328 - accuracy: 0.9892 - val_loss: 0.6618 - val_accuracy: 0.8515
# Epoch 9/30
# 248/250 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9919
# Epoch 9: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.0245 - accuracy: 0.9919 - val_loss: 0.7122 - val_accuracy: 0.8533
# Epoch 10/30
# 245/250 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9938
# Epoch 10: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.0205 - accuracy: 0.9938 - val_loss: 0.7994 - val_accuracy: 0.8543
# Epoch 11/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9939
# Epoch 11: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.8123 - val_accuracy: 0.8558
# Epoch 12/30
# 248/250 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9941
# Epoch 12: val_loss did not improve from 0.32325
# 250/250 [==============================] - 2s 9ms/step - loss: 0.0185 - accuracy: 0.9941 - val_loss: 0.8580 - val_accuracy: 0.8515
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3097 - accuracy: 0.8668
# [0.3097085654735565, 0.8668000102043152]

# %% [markdown]
# - Case 2) Conv1D + LSTM

# %%
model2 = Sequential([
    Embedding(num_words, 100, input_length=max_len),
    Dropout(0.5),
    Conv1D(64, 5, activation='relu'),
    MaxPooling1D(5),
    LSTM(100),
    Dense(1, activation='sigmoid')
])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 100)          1000000
#
#  dropout_1 (Dropout)         (None, 500, 100)          0
#
#  conv1d_2 (Conv1D)           (None, 496, 64)           32064
#
#  max_pooling1d_2 (MaxPooling  (None, 99, 64)           0
#  1D)
#
#  lstm (LSTM)                 (None, 100)               66000
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 1,098,165
# Trainable params: 1,098,165
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile('adam', 'binary_crossentropy', ['accuracy'])
model_path2 = 'best-imdb-conv1d-lstm.h5'
mc2 = ModelCheckpoint(model_path2, verbose=1, save_best_only=True)
es2 = EarlyStopping(patience=10)
hist2 = model2.fit(
    X_train, y_train, validation_split=0.2,
    epochs=30, batch_size=64, callbacks=[mc2,es2]
)
best_model2 = load_model(model_path2)
best_model2.evaluate(X_test, y_test)
# Out:
# Epoch 1/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.4414 - accuracy: 0.7668
# Epoch 1: val_loss improved from inf to 0.29528, saving model to best-imdb-conv1d-lstm.h5
# 250/250 [==============================] - 7s 16ms/step - loss: 0.4410 - accuracy: 0.7673 - val_loss: 0.2953 - val_accuracy: 0.8827
# Epoch 2/30
# 246/250 [============================>.] - ETA: 0s - loss: 0.2164 - accuracy: 0.9153
# Epoch 2: val_loss improved from 0.29528 to 0.26531, saving model to best-imdb-conv1d-lstm.h5
# 250/250 [==============================] - 4s 15ms/step - loss: 0.2173 - accuracy: 0.9149 - val_loss: 0.2653 - val_accuracy: 0.8905
# Epoch 3/30
# 248/250 [============================>.] - ETA: 0s - loss: 0.1410 - accuracy: 0.9488
# Epoch 3: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 14ms/step - loss: 0.1411 - accuracy: 0.9486 - val_loss: 0.3011 - val_accuracy: 0.8770
# Epoch 4/30
# 246/250 [============================>.] - ETA: 0s - loss: 0.0975 - accuracy: 0.9670
# Epoch 4: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 13ms/step - loss: 0.0981 - accuracy: 0.9668 - val_loss: 0.3231 - val_accuracy: 0.8790
# Epoch 5/30
# 250/250 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9781
# Epoch 5: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 13ms/step - loss: 0.0662 - accuracy: 0.9781 - val_loss: 0.3748 - val_accuracy: 0.8848
# Epoch 6/30
# 248/250 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9832
# Epoch 6: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 14ms/step - loss: 0.0517 - accuracy: 0.9830 - val_loss: 0.4438 - val_accuracy: 0.8655
# Epoch 7/30
# 246/250 [============================>.] - ETA: 0s - loss: 0.0437 - accuracy: 0.9852
# Epoch 7: val_loss did not improve from 0.26531
# 250/250 [==============================] - 4s 14ms/step - loss: 0.0442 - accuracy: 0.9851 - val_loss: 0.4430 - val_accuracy: 0.8770
# Epoch 8/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9886
# Epoch 8: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 13ms/step - loss: 0.0335 - accuracy: 0.9886 - val_loss: 0.5319 - val_accuracy: 0.8780
# Epoch 9/30
# 246/250 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9889
# Epoch 9: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 13ms/step - loss: 0.0331 - accuracy: 0.9888 - val_loss: 0.5218 - val_accuracy: 0.8820
# Epoch 10/30
# 246/250 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9922
# Epoch 10: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 13ms/step - loss: 0.0244 - accuracy: 0.9920 - val_loss: 0.5067 - val_accuracy: 0.8798
# Epoch 11/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9936
# Epoch 11: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 13ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.5398 - val_accuracy: 0.8805
# Epoch 12/30
# 247/250 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9934
# Epoch 12: val_loss did not improve from 0.26531
# 250/250 [==============================] - 3s 13ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.5999 - val_accuracy: 0.8845
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2721 - accuracy: 0.8874
# [0.2721376121044159, 0.8873999714851379]

# %% [markdown]
# - Case 3) Conv1D + Dense

# %%
model3 = Sequential([
    Embedding(num_words, 100, input_length=max_len),
    Dropout(0.5),
    Conv1D(64, 5, activation='relu'),
    MaxPooling1D(5),
    GlobalMaxPooling1D(),
    Dense(100, activation='relu'),
    Dense(1, activation='sigmoid')
])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 500, 100)          1000000
#
#  dropout_2 (Dropout)         (None, 500, 100)          0
#
#  conv1d_3 (Conv1D)           (None, 496, 64)           32064
#
#  max_pooling1d_3 (MaxPooling  (None, 99, 64)           0
#  1D)
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 100)               6500
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 1,038,665
# Trainable params: 1,038,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile('adam', 'binary_crossentropy', ['accuracy'])
model_path3 = 'best-imdb-conv1d-dense.h5'
mc3 = ModelCheckpoint(model_path3, verbose=1, save_best_only=True)
es3 = EarlyStopping(patience=10)
hist3 = model3.fit(
    X_train, y_train, validation_split=0.2,
    epochs=30, batch_size=64, callbacks=[mc3,es3]
)
best_model3 = load_model(model_path3)
best_model3.evaluate(X_test, y_test)
# Out:
# Epoch 1/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.5796 - accuracy: 0.6644
# Epoch 1: val_loss improved from inf to 0.38888, saving model to best-imdb-conv1d-dense.h5
# 250/250 [==============================] - 3s 9ms/step - loss: 0.5789 - accuracy: 0.6652 - val_loss: 0.3889 - val_accuracy: 0.8282
# Epoch 2/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.3139 - accuracy: 0.8687
# Epoch 2: val_loss improved from 0.38888 to 0.30136, saving model to best-imdb-conv1d-dense.h5
# 250/250 [==============================] - 2s 9ms/step - loss: 0.3144 - accuracy: 0.8685 - val_loss: 0.3014 - val_accuracy: 0.8742
# Epoch 3/30
# 250/250 [==============================] - ETA: 0s - loss: 0.2099 - accuracy: 0.9185
# Epoch 3: val_loss improved from 0.30136 to 0.29671, saving model to best-imdb-conv1d-dense.h5
# 250/250 [==============================] - 2s 8ms/step - loss: 0.2099 - accuracy: 0.9185 - val_loss: 0.2967 - val_accuracy: 0.8770
# Epoch 4/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.1407 - accuracy: 0.9489
# Epoch 4: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.1409 - accuracy: 0.9489 - val_loss: 0.3100 - val_accuracy: 0.8838
# Epoch 5/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.0936 - accuracy: 0.9671
# Epoch 5: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0939 - accuracy: 0.9671 - val_loss: 0.3507 - val_accuracy: 0.8815
# Epoch 6/30
# 248/250 [============================>.] - ETA: 0s - loss: 0.0608 - accuracy: 0.9801
# Epoch 6: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0606 - accuracy: 0.9802 - val_loss: 0.3719 - val_accuracy: 0.8805
# Epoch 7/30
# 247/250 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9865
# Epoch 7: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0416 - accuracy: 0.9864 - val_loss: 0.4466 - val_accuracy: 0.8723
# Epoch 8/30
# 247/250 [============================>.] - ETA: 0s - loss: 0.0377 - accuracy: 0.9875
# Epoch 8: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0376 - accuracy: 0.9875 - val_loss: 0.4302 - val_accuracy: 0.8813
# Epoch 9/30
# 244/250 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 0.9912
# Epoch 9: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0250 - accuracy: 0.9911 - val_loss: 0.4649 - val_accuracy: 0.8760
# Epoch 10/30
# 245/250 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9912
# Epoch 10: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0247 - accuracy: 0.9911 - val_loss: 0.4894 - val_accuracy: 0.8795
# Epoch 11/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 0.9923
# Epoch 11: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0222 - accuracy: 0.9923 - val_loss: 0.5038 - val_accuracy: 0.8815
# Epoch 12/30
# 249/250 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 0.9945
# Epoch 12: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.5693 - val_accuracy: 0.8755
# Epoch 13/30
# 245/250 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9923
# Epoch 13: val_loss did not improve from 0.29671
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 0.5578 - val_accuracy: 0.8780
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3079 - accuracy: 0.8740
# [0.307894766330719, 0.8740000128746033]
