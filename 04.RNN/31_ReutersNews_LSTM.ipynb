# %% [markdown]
# # 로이터 뉴스 분류하기 - LSTM

# %% [markdown]
# ### 데이터 탐색

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import reuters

# %%
(X_train, y_train), (X_test, y_test) = reuters.load_data()
len(X_train), len(X_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step
# (8982, 2246)

# %%
# 카테고리 개수
max(y_train) + 1
# Out:
# 46

# %%
y_train
# Out:
# array([ 3,  4,  3, ..., 25,  3, 25])

# %%
X_train
# Out:
# array([list([1, 27595, 28842, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]),
#        list([1, 3267, 699, 3434, 2295, 56, 16784, 7511, 9, 56, 3906, 1073, 81, 5, 1198, 57, 366, 737, 132, 20, 4093, 7, 19261, 49, 2295, 13415, 1037, 3267, 699, 3434, 8, 7, 10, 241, 16, 855, 129, 231, 783, 5, 4, 587, 2295, 13415, 30625, 775, 7, 48, 34, 191, 44, 35, 1795, 505, 17, 12]),
#        list([1, 53, 12, 284, 15, 14, 272, 26, 53, 959, 32, 818, 15, 14, 272, 26, 39, 684, 70, 11, 14, 12, 3886, 18, 180, 183, 187, 70, 11, 14, 102, 32, 11, 29, 53, 44, 704, 15, 14, 19, 758, 15, 53, 959, 47, 1013, 15, 14, 19, 132, 15, 39, 965, 32, 11, 14, 147, 72, 11, 180, 183, 187, 44, 11, 14, 102, 19, 11, 123, 186, 90, 67, 960, 4, 78, 13, 68, 467, 511, 110, 59, 89, 90, 67, 1390, 55, 2678, 92, 617, 80, 1274, 46, 905, 220, 13, 4, 346, 48, 235, 629, 5, 211, 5, 1118, 7, 11733, 81, 5, 187, 11, 15, 9, 1709, 201, 5, 47, 3615, 18, 478, 4514, 5, 1118, 7, 232, 13051, 71, 5, 160, 63, 11, 9, 26503, 81, 5, 102, 59, 11, 17, 12]),
#        ...,
#        list([1, 141, 3890, 387, 81, 8, 16, 1629, 10, 340, 1241, 850, 31, 56, 3890, 691, 9, 1241, 71, 9, 5985, 16338, 19170, 699, 19886, 13441, 18064, 699, 244, 5945, 4, 49, 8, 4, 656, 850, 33, 2993, 9, 2139, 340, 3371, 1493, 9, 17870, 22, 16964, 1094, 687, 83, 35, 15, 257, 6, 57, 9190, 7, 4, 5956, 654, 5, 17822, 6191, 1371, 4, 49, 8, 16, 369, 646, 6, 1076, 7, 124, 407, 17, 12]),
#        list([1, 53, 46, 957, 26, 14, 74, 132, 26, 39, 46, 258, 3614, 18, 14, 74, 134, 5131, 18, 88, 2321, 72, 11, 14, 1842, 32, 11, 123, 383, 89, 39, 46, 235, 10, 864, 728, 5, 258, 44, 11, 15, 22, 753, 9, 42, 92, 131, 728, 5, 69, 312, 11, 15, 22, 222, 10964, 3237, 383, 48, 39, 74, 235, 10, 864, 276, 5, 61, 32, 11, 15, 21, 4, 211, 5, 126, 1072, 42, 92, 131, 46, 19, 352, 11, 15, 22, 710, 220, 9, 42, 92, 131, 276, 5, 59, 61, 11, 15, 22, 10, 455, 7, 1172, 137, 336, 1325, 6, 1532, 142, 971, 6463, 43, 359, 5, 4, 326, 753, 364, 17, 12]),
#        list([1, 227, 2406, 91, 21969, 125, 2855, 21, 4, 3976, 76, 7, 4, 757, 481, 3976, 790, 5259, 5654, 9, 111, 149, 8, 7, 10, 76, 223, 51, 4, 417, 8, 1047, 91, 6917, 1688, 340, 7, 194, 9411, 6, 1894, 21, 127, 2151, 2394, 1456, 6, 3034, 4, 329, 433, 7, 65, 87, 1127, 10, 8219, 1475, 290, 9, 21, 567, 16, 1926, 24, 4, 76, 209, 30, 4033, 6655, 5654, 8, 4, 60, 8, 4, 966, 308, 40, 2575, 129, 15562, 295, 277, 1071, 9, 24, 286, 2114, 234, 222, 9, 4, 906, 3994, 8519, 114, 5758, 1752, 7, 4, 113, 17, 12])],
#       dtype=object)

# %%
type(reuters.get_word_index())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 0s 0us/step
# 565248/550378 [==============================] - 0s 0us/step
# dict

# %%
reuters.get_word_index()['the']
# Out:
# 1

# %%
index_word = {}
for key, value in reuters.get_word_index().items():
    index_word[value] = key
len(index_word)
# Out:
# 30979

# %%
# 첫 번째 기사 복원
' '.join(index_word[index] for index in X_train[0])
# Out:
# 'the wattie nondiscriminatory mln loss for plc said at only ended said commonwealth could 1 traders now april 0 a after said from 1985 and from foreign 000 april 0 prices its account year a but in this mln home an states earlier and rise and revs vs 000 its 16 vs 000 a but 3 psbr oils several and shareholders and dividend vs 000 its all 4 vs 000 1 mln agreed largely april 0 are 2 states will billion total and against 000 pct dlrs'

# %%
# 뉴스 기사의 길이
max(len(s) for s in X_train), sum(map(len, X_train)) / len(X_train)
# Out:
# (2376, 145.5398574927633)

# %%
# 뉴스 기사 단어수의 분포
plt.figure(figsize=(12,4))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples');

# %%
# 뉴스 그룹의 분포
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(12,5))
sns.countplot(y_train);

# %% [markdown]
# ### LSTM으로 로이터 뉴스 분류
# - 문장길이: 100 단어 까지 (최대 2,376)
# - 단어: 빈도수 기준 1,000 (총단어수 30,975)

# %%
max_words = 1000
max_len = 100

# %%
(X_train, y_train), (X_test, y_test) = reuters.load_data(
    num_words=max_words, test_split=0.2
)

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((8982, 100), (2246, 100), (8982, 46), (2246, 46))

# %% [markdown]
# - 모델 정의/설정/학습

# %%
model = Sequential([
    Embedding(max_words, 64, input_length=max_len),
    LSTM(100),
    Dense(46, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 64)           64000
#
#  lstm (LSTM)                 (None, 100)               66000
#
#  dense (Dense)               (None, 46)                4646
#
# =================================================================
# Total params: 134,646
# Trainable params: 134,646
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

# %%
model_path = 'best-reuters-lstm.h5'
mc = ModelCheckpoint(model_path, verbose=1, save_best_only=True)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=128, callbacks=[mc,es]
)
# Out:
# Epoch 1/100
# 53/57 [==========================>...] - ETA: 0s - loss: 2.7372 - accuracy: 0.3284
# Epoch 1: val_loss improved from inf to 2.40400, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 8s 22ms/step - loss: 2.7159 - accuracy: 0.3317 - val_loss: 2.4040 - val_accuracy: 0.3450
# Epoch 2/100
# 53/57 [==========================>...] - ETA: 0s - loss: 2.4126 - accuracy: 0.3505
# Epoch 2: val_loss improved from 2.40400 to 2.38775, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 2.4047 - accuracy: 0.3534 - val_loss: 2.3877 - val_accuracy: 0.3450
# Epoch 3/100
# 54/57 [===========================>..] - ETA: 0s - loss: 2.1908 - accuracy: 0.4363
# Epoch 3: val_loss improved from 2.38775 to 2.03323, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 12ms/step - loss: 2.1862 - accuracy: 0.4390 - val_loss: 2.0332 - val_accuracy: 0.4775
# Epoch 4/100
# 53/57 [==========================>...] - ETA: 0s - loss: 1.9614 - accuracy: 0.4901
# Epoch 4: val_loss improved from 2.03323 to 1.91780, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.9571 - accuracy: 0.4919 - val_loss: 1.9178 - val_accuracy: 0.5025
# Epoch 5/100
# 57/57 [==============================] - ETA: 0s - loss: 1.8374 - accuracy: 0.5275
# Epoch 5: val_loss improved from 1.91780 to 1.79835, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 12ms/step - loss: 1.8374 - accuracy: 0.5275 - val_loss: 1.7984 - val_accuracy: 0.5259
# Epoch 6/100
# 52/57 [==========================>...] - ETA: 0s - loss: 1.7480 - accuracy: 0.5419
# Epoch 6: val_loss improved from 1.79835 to 1.76929, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 1.7511 - accuracy: 0.5418 - val_loss: 1.7693 - val_accuracy: 0.5403
# Epoch 7/100
# 53/57 [==========================>...] - ETA: 0s - loss: 1.6943 - accuracy: 0.5619
# Epoch 7: val_loss improved from 1.76929 to 1.69075, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.6927 - accuracy: 0.5613 - val_loss: 1.6907 - val_accuracy: 0.5659
# Epoch 8/100
# 53/57 [==========================>...] - ETA: 0s - loss: 1.6567 - accuracy: 0.5712
# Epoch 8: val_loss improved from 1.69075 to 1.67038, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 12ms/step - loss: 1.6611 - accuracy: 0.5704 - val_loss: 1.6704 - val_accuracy: 0.5615
# Epoch 9/100
# 54/57 [===========================>..] - ETA: 0s - loss: 1.6316 - accuracy: 0.5843
# Epoch 9: val_loss improved from 1.67038 to 1.63336, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.6389 - accuracy: 0.5822 - val_loss: 1.6334 - val_accuracy: 0.5810
# Epoch 10/100
# 55/57 [===========================>..] - ETA: 0s - loss: 1.5728 - accuracy: 0.6053
# Epoch 10: val_loss improved from 1.63336 to 1.56515, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.5687 - accuracy: 0.6071 - val_loss: 1.5651 - val_accuracy: 0.6099
# Epoch 11/100
# 52/57 [==========================>...] - ETA: 0s - loss: 1.4987 - accuracy: 0.6252
# Epoch 11: val_loss improved from 1.56515 to 1.55247, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.4974 - accuracy: 0.6244 - val_loss: 1.5525 - val_accuracy: 0.6060
# Epoch 12/100
# 54/57 [===========================>..] - ETA: 0s - loss: 1.4558 - accuracy: 0.6296
# Epoch 12: val_loss improved from 1.55247 to 1.49275, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.4520 - accuracy: 0.6303 - val_loss: 1.4927 - val_accuracy: 0.6288
# Epoch 13/100
# 55/57 [===========================>..] - ETA: 0s - loss: 1.4024 - accuracy: 0.6438
# Epoch 13: val_loss did not improve from 1.49275
# 57/57 [==============================] - 1s 11ms/step - loss: 1.4038 - accuracy: 0.6433 - val_loss: 1.5327 - val_accuracy: 0.6093
# Epoch 14/100
# 54/57 [===========================>..] - ETA: 0s - loss: 1.4052 - accuracy: 0.6389
# Epoch 14: val_loss improved from 1.49275 to 1.46902, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.3999 - accuracy: 0.6406 - val_loss: 1.4690 - val_accuracy: 0.6294
# Epoch 15/100
# 52/57 [==========================>...] - ETA: 0s - loss: 1.3735 - accuracy: 0.6451
# Epoch 15: val_loss improved from 1.46902 to 1.46254, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.3789 - accuracy: 0.6430 - val_loss: 1.4625 - val_accuracy: 0.6355
# Epoch 16/100
# 54/57 [===========================>..] - ETA: 0s - loss: 1.3059 - accuracy: 0.6648
# Epoch 16: val_loss improved from 1.46254 to 1.39395, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.3027 - accuracy: 0.6654 - val_loss: 1.3939 - val_accuracy: 0.6500
# Epoch 17/100
# 54/57 [===========================>..] - ETA: 0s - loss: 1.2501 - accuracy: 0.6781
# Epoch 17: val_loss improved from 1.39395 to 1.38959, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.2512 - accuracy: 0.6781 - val_loss: 1.3896 - val_accuracy: 0.6589
# Epoch 18/100
# 52/57 [==========================>...] - ETA: 0s - loss: 1.2151 - accuracy: 0.6907
# Epoch 18: val_loss improved from 1.38959 to 1.35277, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 1.2098 - accuracy: 0.6923 - val_loss: 1.3528 - val_accuracy: 0.6683
# Epoch 19/100
# 52/57 [==========================>...] - ETA: 0s - loss: 1.1927 - accuracy: 0.6977
# Epoch 19: val_loss improved from 1.35277 to 1.35149, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.1852 - accuracy: 0.6987 - val_loss: 1.3515 - val_accuracy: 0.6656
# Epoch 20/100
# 55/57 [===========================>..] - ETA: 0s - loss: 1.1429 - accuracy: 0.7094
# Epoch 20: val_loss improved from 1.35149 to 1.32194, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 12ms/step - loss: 1.1406 - accuracy: 0.7093 - val_loss: 1.3219 - val_accuracy: 0.6884
# Epoch 21/100
# 52/57 [==========================>...] - ETA: 0s - loss: 1.1045 - accuracy: 0.7181
# Epoch 21: val_loss improved from 1.32194 to 1.29997, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 12ms/step - loss: 1.0953 - accuracy: 0.7215 - val_loss: 1.3000 - val_accuracy: 0.6834
# Epoch 22/100
# 53/57 [==========================>...] - ETA: 0s - loss: 1.0556 - accuracy: 0.7317
# Epoch 22: val_loss improved from 1.29997 to 1.28804, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.0598 - accuracy: 0.7318 - val_loss: 1.2880 - val_accuracy: 0.6934
# Epoch 23/100
# 54/57 [===========================>..] - ETA: 0s - loss: 1.0666 - accuracy: 0.7316
# Epoch 23: val_loss did not improve from 1.28804
# 57/57 [==============================] - 1s 11ms/step - loss: 1.0659 - accuracy: 0.7318 - val_loss: 1.2960 - val_accuracy: 0.6956
# Epoch 24/100
# 53/57 [==========================>...] - ETA: 0s - loss: 1.0080 - accuracy: 0.7400
# Epoch 24: val_loss improved from 1.28804 to 1.26181, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 1.0091 - accuracy: 0.7393 - val_loss: 1.2618 - val_accuracy: 0.6939
# Epoch 25/100
# 54/57 [===========================>..] - ETA: 0s - loss: 0.9577 - accuracy: 0.7520
# Epoch 25: val_loss did not improve from 1.26181
# 57/57 [==============================] - 1s 11ms/step - loss: 0.9559 - accuracy: 0.7534 - val_loss: 1.2740 - val_accuracy: 0.7095
# Epoch 26/100
# 55/57 [===========================>..] - ETA: 0s - loss: 0.9322 - accuracy: 0.7626
# Epoch 26: val_loss did not improve from 1.26181
# 57/57 [==============================] - 1s 10ms/step - loss: 0.9349 - accuracy: 0.7623 - val_loss: 1.2641 - val_accuracy: 0.6917
# Epoch 27/100
# 54/57 [===========================>..] - ETA: 0s - loss: 0.9153 - accuracy: 0.7653
# Epoch 27: val_loss improved from 1.26181 to 1.24740, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 11ms/step - loss: 0.9131 - accuracy: 0.7659 - val_loss: 1.2474 - val_accuracy: 0.7017
# Epoch 28/100
# 57/57 [==============================] - ETA: 0s - loss: 0.8903 - accuracy: 0.7748
# Epoch 28: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8903 - accuracy: 0.7748 - val_loss: 1.2700 - val_accuracy: 0.7045
# Epoch 29/100
# 57/57 [==============================] - ETA: 0s - loss: 0.8685 - accuracy: 0.7797
# Epoch 29: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8685 - accuracy: 0.7797 - val_loss: 1.2604 - val_accuracy: 0.7078
# Epoch 30/100
# 53/57 [==========================>...] - ETA: 0s - loss: 0.8425 - accuracy: 0.7851
# Epoch 30: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8386 - accuracy: 0.7875 - val_loss: 1.2500 - val_accuracy: 0.7101
# Epoch 31/100
# 52/57 [==========================>...] - ETA: 0s - loss: 0.8253 - accuracy: 0.7879
# Epoch 31: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8251 - accuracy: 0.7890 - val_loss: 1.2617 - val_accuracy: 0.7145
# Epoch 32/100
# 54/57 [===========================>..] - ETA: 0s - loss: 0.7895 - accuracy: 0.8032
# Epoch 32: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.7929 - accuracy: 0.8031 - val_loss: 1.3441 - val_accuracy: 0.6822
# Epoch 33/100
# 52/57 [==========================>...] - ETA: 0s - loss: 0.8059 - accuracy: 0.7955
# Epoch 33: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 13ms/step - loss: 0.8095 - accuracy: 0.7957 - val_loss: 1.2480 - val_accuracy: 0.7123
# Epoch 34/100
# 54/57 [===========================>..] - ETA: 0s - loss: 0.7566 - accuracy: 0.8098
# Epoch 34: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.7567 - accuracy: 0.8085 - val_loss: 1.2593 - val_accuracy: 0.7162
# Epoch 35/100
# 54/57 [===========================>..] - ETA: 0s - loss: 0.7157 - accuracy: 0.8192
# Epoch 35: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.7197 - accuracy: 0.8191 - val_loss: 1.2713 - val_accuracy: 0.7051
# Epoch 36/100
# 56/57 [============================>.] - ETA: 0s - loss: 0.6963 - accuracy: 0.8213
# Epoch 36: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.6952 - accuracy: 0.8216 - val_loss: 1.2610 - val_accuracy: 0.7062
# Epoch 37/100
# 52/57 [==========================>...] - ETA: 0s - loss: 0.6552 - accuracy: 0.8364
# Epoch 37: val_loss did not improve from 1.24740
# 57/57 [==============================] - 1s 11ms/step - loss: 0.6603 - accuracy: 0.8348 - val_loss: 1.2788 - val_accuracy: 0.7112

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 1.2540 - accuracy: 0.6910
# [1.2540053129196167, 0.6910062432289124]

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.grid(), plt.legend(), plt.xlabel('Epoch')
plt.show()
